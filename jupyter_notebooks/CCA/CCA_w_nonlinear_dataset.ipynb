# %% [markdown]
# # 0. About
#
# This notebook is to see how CCA would handle non-linear datasets.

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import scipy
import warnings
import time

import sklearn
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.model_selection import RepeatedKFold, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import CCA, PLSCanonical
from sklearn.utils import Bunch
from sklearn.metrics.pairwise import cosine_similarity

from cca_zoo.models import CCA as cz_CCA
from cca_zoo.models import rCCA as cz_rCCA
from cca_zoo.model_selection import GridSearchCV as cz_GridSearchCV
from cca_zoo.plotting import pairplot_train_test

rs_num = 14
rng = np.random.default_rng(rs_num)

sklearn.set_config(display="diagram")

n_splits = 5
n_repeats = 50

# %matplotlib inline

# %% [markdown]
# # 1. Dataset Construction

# %%
sample_num = 200
X_dimension_num = 7
Y_dimension_num = 8

# construct X
X = rng.normal(loc=0.0, scale=1.0, size=(sample_num, X_dimension_num))

# noise
xi_1 = rng.normal(loc=0, scale=np.sqrt(0.2), size=(sample_num, ))
xi_2 = rng.normal(loc=0, scale=np.sqrt(0.4), size=(sample_num, ))
xi_3 = rng.normal(loc=0, scale=np.sqrt(0.3), size=(sample_num, ))

# contruct Y
Y = rng.normal(loc=0.0, scale=1.0, size=(sample_num, Y_dimension_num))
Y[:, 0] = np.exp(X[:, 2]) + xi_1
Y[:, 1] = np.power(X[:, 0], 3) + xi_2
Y[:, 2] = -X[:, 3] + xi_3

# split them into training and test dataset
[X_train, X_test, Y_train, Y_test] = train_test_split(
    X, Y, test_size=0.20, random_state=rs_num
)

# %%
# standardization of two matrices
X_train_scaler = StandardScaler().fit(X_train)
X_train_standardized = X_train_scaler.transform(X_train)
X_test_standardized = X_train_scaler.transform(X_test)

Y_train_scaler = StandardScaler().fit(Y_train)
Y_train_standardized = Y_train_scaler.transform(Y_train)
Y_test_standardized = Y_train_scaler.transform(Y_test)

# %% [markdown]
# # 2. Regularized CCA

# %%
# we need to define the scoring method with customized scoring function
# ref: https://github.com/jameschapman19/cca_zoo/issues/150
def scoring_func(estimator, views):
    return np.nanmean(estimator.score(views))

# %%
rcca_bunch = Bunch()
rcca_bunch.name = 'rcca'

rcca_bunch.n_components = np.min([X_dimension_num, Y_dimension_num])

rcca_bunch.rkf = RepeatedKFold(
    n_splits=n_splits, n_repeats=n_repeats, random_state=rs_num
)

# %% [markdown]
# ## 2.1. Grid Search for Optimal Regularization Parameters

# %%
# set up grids
rcca_bunch.c1_list = [0.95*i for i in np.logspace(-2, 0, 21)] # regularization parameter
rcca_bunch.c2_list = [0.95*i for i in np.logspace(-2, 0, 21)] # regularization parameter

rcca_bunch.param_grid = {
    'c': [rcca_bunch.c1_list, rcca_bunch.c2_list]
}

# %%
# starting of the track of computing time
t_start = time.time()

# ignore warnings for some bad searching
warnings.filterwarnings('ignore')

# searching for best parameters
rcca_bunch.gscv_results = cz_GridSearchCV(
    cz_rCCA(
        latent_dims=rcca_bunch.n_components, 
        random_state=rs_num
    ), 
    param_grid=rcca_bunch.param_grid, 
    scoring=scoring_func, 
    cv=rcca_bunch.rkf
).fit([X_train, Y_train])

# reset warnings
warnings.resetwarnings()

# ending of the track of computing time
t_elapsed = time.time() - t_start

# %%
print('Above cell computation takes {:.1f} seconds.'.format(t_elapsed))
# Out:
# Above cell computation takes 617.5 seconds.

# %%
# rearrange parameter grid
param_grid_c1_arr_viz = np.zeros_like(
    rcca_bunch.gscv_results.cv_results_['param_estimator__c'].data
)
param_grid_c2_arr_viz = np.zeros_like(param_grid_c1_arr_viz)

for param_i, param_list in enumerate(
    rcca_bunch.gscv_results.cv_results_['param_estimator__c'].data
):
    param_grid_c1_arr_viz[param_i] = param_list[0]
    param_grid_c2_arr_viz[param_i] = param_list[1]

# %%
fig, ax = plt.subplots()

sc = ax.scatter(
    param_grid_c1_arr_viz, 
    param_grid_c2_arr_viz, 
    c=rcca_bunch.gscv_results.cv_results_['mean_test_score'], 
    s=5
)
cbar = plt.colorbar(sc)
cbar.set_label('Mean Test Score (Canonical Correlation)')
ax.scatter(
    rcca_bunch.gscv_results.best_params_['c'][0], 
    rcca_bunch.gscv_results.best_params_['c'][1], 
    marker='o',
    ec='royalblue', 
    fc='none', 
    label='best'
)

ax.set(
    xscale='log', 
    yscale='log', 
    xlabel='$c_1$', 
    ylabel='$c_2$', 
    title=(
        'Grid Search with {}-repeat {}-fold CV'.format(n_splits, n_repeats) + 
        '\nfor Optimal Regularization Parameters'
    )
)
ax.legend(
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    fancybox=True,
    shadow=True,
    ncol=1,
    fontsize='small'
)

plt.tight_layout()

# %% [markdown]
# ## 2.2. Check out Optimal Parameters

# %%
print('For regularized CCA:')

# fit cca
rcca_bunch.cca = rcca_bunch.gscv_results.best_estimator_
rcca_bunch.cca.fit((X_train, Y_train))

# transform datasets
[rcca_bunch.Xc_train, 
 rcca_bunch.Yc_train] = rcca_bunch.cca.transform((X_train, Y_train))
[rcca_bunch.Xc_test, 
 rcca_bunch.Yc_test] = rcca_bunch.cca.transform((X_test, Y_test))

# obtain canonical correlations
rcca_bunch.cc_train = rcca_bunch.cca.score((X_train, Y_train))
rcca_bunch.cc_test = rcca_bunch.cca.score((X_test, Y_test))
print('  CC over training dataset: ', rcca_bunch.cc_train)
print('  CC over test dataset: ', rcca_bunch.cc_test)
# Out:
# For regularized CCA:
#   CC over training dataset:  [0.87212858 0.83403392 0.81878478 0.23451957 0.20734457 0.15849802
#  0.03292947]
#   CC over test dataset:  [ 0.85216416  0.7440778   0.89134757 -0.05557443  0.06975235  0.07337765
#  -0.04761022]

# %% [markdown]
# Since for the dataset, we know how variables are correlated, we can directly check out the correlations

# %%
# visualization options
corr_cmap = sns.color_palette('vlag', as_cmap=True)

rcca_bunch.X_corr_check_df = pd.DataFrame(
    data={
        'exp(x3)': np.exp(X_train_standardized[:, 2]), 
        'x1^3': np.power(X_train_standardized[:, 0], 3),
        'x4': X_train_standardized[:, 3], 
        'xc1': rcca_bunch.Xc_train[:, 0], 
        'xc2': rcca_bunch.Xc_train[:, 1], 
        'xc3': rcca_bunch.Xc_train[:, 2]
    }
)

rcca_bunch.X_corr_check_df.corr(
    method='pearson'
).style.background_gradient(cmap=corr_cmap).format(precision=2)
# Out:
# <style type="text/css">
# #T_d9dc8_row0_col0, #T_d9dc8_row1_col1, #T_d9dc8_row2_col2, #T_d9dc8_row3_col3, #T_d9dc8_row4_col4, #T_d9dc8_row5_col5 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_d9dc8_row0_col1 {
#   background-color: #e2e3ea;
#   color: #000000;
# }
# #T_d9dc8_row0_col2 {
#   background-color: #f2f0f2;
#   color: #000000;
# }
# #T_d9dc8_row0_col3, #T_d9dc8_row1_col0 {
#   background-color: #f8f4f5;
#   color: #000000;
# }
# #T_d9dc8_row0_col4, #T_d9dc8_row1_col5, #T_d9dc8_row2_col3, #T_d9dc8_row3_col2, #T_d9dc8_row4_col0, #T_d9dc8_row5_col1 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_d9dc8_row0_col5 {
#   background-color: #cad0dd;
#   color: #000000;
# }
# #T_d9dc8_row1_col2 {
#   background-color: #f4e3e2;
#   color: #000000;
# }
# #T_d9dc8_row1_col3 {
#   background-color: #859ec4;
#   color: #f1f1f1;
# }
# #T_d9dc8_row1_col4, #T_d9dc8_row4_col2 {
#   background-color: #eeedf0;
#   color: #000000;
# }
# #T_d9dc8_row2_col0 {
#   background-color: #ecebef;
#   color: #000000;
# }
# #T_d9dc8_row2_col1 {
#   background-color: #faf5f5;
#   color: #000000;
# }
# #T_d9dc8_row2_col4 {
#   background-color: #e7e7ec;
#   color: #000000;
# }
# #T_d9dc8_row2_col5 {
#   background-color: #e1bab8;
#   color: #000000;
# }
# #T_d9dc8_row3_col0 {
#   background-color: #f3f1f3;
#   color: #000000;
# }
# #T_d9dc8_row3_col1 {
#   background-color: #517fbc;
#   color: #f1f1f1;
# }
# #T_d9dc8_row3_col4, #T_d9dc8_row5_col4 {
#   background-color: #efeef1;
#   color: #000000;
# }
# #T_d9dc8_row3_col5 {
#   background-color: #d7dae4;
#   color: #000000;
# }
# #T_d9dc8_row4_col1 {
#   background-color: #d4d8e2;
#   color: #000000;
# }
# #T_d9dc8_row4_col3 {
#   background-color: #f5f2f4;
#   color: #000000;
# }
# #T_d9dc8_row4_col5 {
#   background-color: #d5d9e3;
#   color: #000000;
# }
# #T_d9dc8_row5_col0 {
#   background-color: #e4e5eb;
#   color: #000000;
# }
# #T_d9dc8_row5_col2 {
#   background-color: #daa9a7;
#   color: #000000;
# }
# #T_d9dc8_row5_col3 {
#   background-color: #f6f3f4;
#   color: #000000;
# }
# </style>
# <table id="T_d9dc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9dc8_level0_col0" class="col_heading level0 col0" >exp(x3)</th>
#       <th id="T_d9dc8_level0_col1" class="col_heading level0 col1" >x1^3</th>
#       <th id="T_d9dc8_level0_col2" class="col_heading level0 col2" >x4</th>
#       <th id="T_d9dc8_level0_col3" class="col_heading level0 col3" >xc1</th>
#       <th id="T_d9dc8_level0_col4" class="col_heading level0 col4" >xc2</th>
#       <th id="T_d9dc8_level0_col5" class="col_heading level0 col5" >xc3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9dc8_level0_row0" class="row_heading level0 row0" >exp(x3)</th>
#       <td id="T_d9dc8_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_d9dc8_row0_col1" class="data row0 col1" >0.05</td>
#       <td id="T_d9dc8_row0_col2" class="data row0 col2" >-0.01</td>
#       <td id="T_d9dc8_row0_col3" class="data row0 col3" >0.02</td>
#       <td id="T_d9dc8_row0_col4" class="data row0 col4" >-0.84</td>
#       <td id="T_d9dc8_row0_col5" class="data row0 col5" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_d9dc8_level0_row1" class="row_heading level0 row1" >x1^3</th>
#       <td id="T_d9dc8_row1_col0" class="data row1 col0" >0.05</td>
#       <td id="T_d9dc8_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_d9dc8_row1_col2" class="data row1 col2" >0.17</td>
#       <td id="T_d9dc8_row1_col3" class="data row1 col3" >-0.52</td>
#       <td id="T_d9dc8_row1_col4" class="data row1 col4" >-0.01</td>
#       <td id="T_d9dc8_row1_col5" class="data row1 col5" >-0.65</td>
#     </tr>
#     <tr>
#       <th id="T_d9dc8_level0_row2" class="row_heading level0 row2" >x4</th>
#       <td id="T_d9dc8_row2_col0" class="data row2 col0" >-0.01</td>
#       <td id="T_d9dc8_row2_col1" class="data row2 col1" >0.17</td>
#       <td id="T_d9dc8_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_d9dc8_row2_col3" class="data row2 col3" >-0.89</td>
#       <td id="T_d9dc8_row2_col4" class="data row2 col4" >-0.04</td>
#       <td id="T_d9dc8_row2_col5" class="data row2 col5" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_d9dc8_level0_row3" class="row_heading level0 row3" >xc1</th>
#       <td id="T_d9dc8_row3_col0" class="data row3 col0" >0.02</td>
#       <td id="T_d9dc8_row3_col1" class="data row3 col1" >-0.52</td>
#       <td id="T_d9dc8_row3_col2" class="data row3 col2" >-0.89</td>
#       <td id="T_d9dc8_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_d9dc8_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_d9dc8_row3_col5" class="data row3 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9dc8_level0_row4" class="row_heading level0 row4" >xc2</th>
#       <td id="T_d9dc8_row4_col0" class="data row4 col0" >-0.84</td>
#       <td id="T_d9dc8_row4_col1" class="data row4 col1" >-0.01</td>
#       <td id="T_d9dc8_row4_col2" class="data row4 col2" >-0.04</td>
#       <td id="T_d9dc8_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_d9dc8_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_d9dc8_row4_col5" class="data row4 col5" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9dc8_level0_row5" class="row_heading level0 row5" >xc3</th>
#       <td id="T_d9dc8_row5_col0" class="data row5 col0" >-0.05</td>
#       <td id="T_d9dc8_row5_col1" class="data row5 col1" >-0.65</td>
#       <td id="T_d9dc8_row5_col2" class="data row5 col2" >0.44</td>
#       <td id="T_d9dc8_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_d9dc8_row5_col4" class="data row5 col4" >-0.00</td>
#       <td id="T_d9dc8_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
rcca_bunch.Y_corr_check_df = pd.DataFrame(
    data={
        'y1': Y_train_standardized[:, 0], 
        'y2': Y_train_standardized[:, 1], 
        'y3': Y_train_standardized[:, 2], 
        'yc1': rcca_bunch.Yc_train[:, 0], 
        'yc2': rcca_bunch.Yc_train[:, 1], 
        'yc3': rcca_bunch.Yc_train[:, 2]
    }
)

rcca_bunch.Y_corr_check_df.corr(
    method='pearson'
).style.background_gradient(cmap=corr_cmap).format(precision=2)
# Out:
# <style type="text/css">
# #T_77011_row0_col0, #T_77011_row1_col1, #T_77011_row2_col2, #T_77011_row3_col3, #T_77011_row4_col4, #T_77011_row5_col5 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_77011_row0_col1, #T_77011_row3_col5, #T_77011_row4_col5 {
#   background-color: #ecebef;
#   color: #000000;
# }
# #T_77011_row0_col2 {
#   background-color: #c3cbda;
#   color: #000000;
# }
# #T_77011_row0_col3 {
#   background-color: #d5d9e3;
#   color: #000000;
# }
# #T_77011_row0_col4, #T_77011_row1_col3, #T_77011_row1_col5, #T_77011_row4_col0, #T_77011_row5_col1, #T_77011_row5_col2 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_77011_row0_col5 {
#   background-color: #e4e5eb;
#   color: #000000;
# }
# #T_77011_row1_col0, #T_77011_row5_col4 {
#   background-color: #faf5f4;
#   color: #000000;
# }
# #T_77011_row1_col2 {
#   background-color: #97abc9;
#   color: #f1f1f1;
# }
# #T_77011_row1_col4, #T_77011_row2_col4, #T_77011_row3_col4 {
#   background-color: #faf5f5;
#   color: #000000;
# }
# #T_77011_row2_col0 {
#   background-color: #faf3f2;
#   color: #000000;
# }
# #T_77011_row2_col1 {
#   background-color: #cfd4e0;
#   color: #000000;
# }
# #T_77011_row2_col3 {
#   background-color: #b85857;
#   color: #f1f1f1;
# }
# #T_77011_row2_col5 {
#   background-color: #7d99c2;
#   color: #f1f1f1;
# }
# #T_77011_row3_col0 {
#   background-color: #faf3f3;
#   color: #000000;
# }
# #T_77011_row3_col1 {
#   background-color: #6288bd;
#   color: #f1f1f1;
# }
# #T_77011_row3_col2 {
#   background-color: #b95a59;
#   color: #f1f1f1;
# }
# #T_77011_row4_col1 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_77011_row4_col2 {
#   background-color: #b8c3d5;
#   color: #000000;
# }
# #T_77011_row4_col3 {
#   background-color: #cbd1de;
#   color: #000000;
# }
# #T_77011_row5_col0 {
#   background-color: #f8f4f5;
#   color: #000000;
# }
# #T_77011_row5_col3 {
#   background-color: #cdd3df;
#   color: #000000;
# }
# </style>
# <table id="T_77011">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77011_level0_col0" class="col_heading level0 col0" >y1</th>
#       <th id="T_77011_level0_col1" class="col_heading level0 col1" >y2</th>
#       <th id="T_77011_level0_col2" class="col_heading level0 col2" >y3</th>
#       <th id="T_77011_level0_col3" class="col_heading level0 col3" >yc1</th>
#       <th id="T_77011_level0_col4" class="col_heading level0 col4" >yc2</th>
#       <th id="T_77011_level0_col5" class="col_heading level0 col5" >yc3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77011_level0_row0" class="row_heading level0 row0" >y1</th>
#       <td id="T_77011_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_77011_row0_col1" class="data row0 col1" >0.01</td>
#       <td id="T_77011_row0_col2" class="data row0 col2" >0.04</td>
#       <td id="T_77011_row0_col3" class="data row0 col3" >0.03</td>
#       <td id="T_77011_row0_col4" class="data row0 col4" >-0.99</td>
#       <td id="T_77011_row0_col5" class="data row0 col5" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_77011_level0_row1" class="row_heading level0 row1" >y2</th>
#       <td id="T_77011_row1_col0" class="data row1 col0" >0.01</td>
#       <td id="T_77011_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_77011_row1_col2" class="data row1 col2" >-0.12</td>
#       <td id="T_77011_row1_col3" class="data row1 col3" >-0.59</td>
#       <td id="T_77011_row1_col4" class="data row1 col4" >-0.00</td>
#       <td id="T_77011_row1_col5" class="data row1 col5" >-0.80</td>
#     </tr>
#     <tr>
#       <th id="T_77011_level0_row2" class="row_heading level0 row2" >y3</th>
#       <td id="T_77011_row2_col0" class="data row2 col0" >0.04</td>
#       <td id="T_77011_row2_col1" class="data row2 col1" >-0.12</td>
#       <td id="T_77011_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_77011_row2_col3" class="data row2 col3" >0.87</td>
#       <td id="T_77011_row2_col4" class="data row2 col4" >-0.00</td>
#       <td id="T_77011_row2_col5" class="data row2 col5" >-0.48</td>
#     </tr>
#     <tr>
#       <th id="T_77011_level0_row3" class="row_heading level0 row3" >yc1</th>
#       <td id="T_77011_row3_col0" class="data row3 col0" >0.03</td>
#       <td id="T_77011_row3_col1" class="data row3 col1" >-0.59</td>
#       <td id="T_77011_row3_col2" class="data row3 col2" >0.87</td>
#       <td id="T_77011_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_77011_row3_col4" class="data row3 col4" >-0.00</td>
#       <td id="T_77011_row3_col5" class="data row3 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_77011_level0_row4" class="row_heading level0 row4" >yc2</th>
#       <td id="T_77011_row4_col0" class="data row4 col0" >-0.99</td>
#       <td id="T_77011_row4_col1" class="data row4 col1" >-0.00</td>
#       <td id="T_77011_row4_col2" class="data row4 col2" >-0.00</td>
#       <td id="T_77011_row4_col3" class="data row4 col3" >-0.00</td>
#       <td id="T_77011_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_77011_row4_col5" class="data row4 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_77011_level0_row5" class="row_heading level0 row5" >yc3</th>
#       <td id="T_77011_row5_col0" class="data row5 col0" >-0.03</td>
#       <td id="T_77011_row5_col1" class="data row5 col1" >-0.80</td>
#       <td id="T_77011_row5_col2" class="data row5 col2" >-0.48</td>
#       <td id="T_77011_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_77011_row5_col4" class="data row5 col4" >0.01</td>
#       <td id="T_77011_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>
